# %%
Age = 23
Vehicles = 200

# %%
type(Age)
# Out:
# int

# %%
type(Vehicles)
# Out:
# int

# %%
Height = 5.6
Price = 35.89
# Out:
# float

# %%
type(Height)
# Out:
# float

# %%
type(Price)
# Out:
# float

# %%
Name = "Amit Kumar"
Course = "Python"
# Out:
# str

# %%
type(Name)
# Out:
# str

# %%
type(Course)
# Out:
# str

# %%
Logged_in = True
Registered = False
# Out:
# bool

# %%
type(Logged_in)
# Out:
# bool

# %%
type(Registered)
# Out:
# bool

# %%
Fruits = ["Apple", "Mango", "Banana", "Orange"]
Vegetables = ["Potato", "Onion", "Tomato"]
# Out:
# list

# %%
type(Fruits)
# Out:
# list

# %%
type(Vegetables)
# Out:
# list

# %%
Students = ("Rahul", "Priya", "Sneha", "Abhisekh", "Amit")
Length = (22, 25.46, 98.97, 100)
# Out:
# tuple

# %%
type(Students)
# Out:
# tuple

# %%
type(Length)
# Out:
# tuple

# %%
Marks = {78, 77 ,75, 60, 98}
Unique_names = {"John", "Sam Altman", "Elon Musk"}
# Out:
# set

# %%
type(Marks)
# Out:
# set

# %%
type(Unique_names)
# Out:
# set

# %%
Employee =  {"Name": "Amit", "Age": 33, "Department": "Product Development"}
Department = {"Support": 100, "Quality": 50, "Sales": 90, "Product Development": 45}
# Out:
# dict

# %%
type(Employee)
# Out:
# dict

# %%
type(Department)
# Out:
# dict

# %% [markdown]
# ### Data type conversion or Typecasting

# %%
int("100") #string to integer
# Out:
# 100

# %%
int("500") #string to integer
# Out:
# 500

# %%
float("45.67") #string to float
# Out:
# 45.67

# %%
float("89.45") #string to float
# Out:
# 89.45

# %%
str(500) #integer to string
# Out:
# '500'

# %%
str(1000) #integer to string
# Out:
# '1000'

# %%
bool(1) #integer to boolean
# Out:
# False

# %%
bool(0) #integer to boolean
# Out:
# False

# %%
list((1, 2, 3)) #tuple to list
# Out:
# [9, 45, 67.54]

# %%
list((9,45,67.54)) #tuple to list
# Out:
# [9, 45, 67.54]

# %%
tuple([1, 2, 3]) #list to tuple
# Out:
# (34, 67, 90)

# %%
tuple([99, 2.2, 7.93]) #list to tuple
# Out:
# (99, 2.2, 7.93)

# %%
tuple({34,67,90}) #set to tuple
# Out:
# (34, 67, 90)

# %%
tuple({67, 24, 99, 43}) #set to tuple
# Out:
# (24, 99, 67, 43)

# %%
set([1, 2, 2, 3]) #list to set
# Out:
# {21, 34, 78}

# %%
set([21,78,34]) #list to set
# Out:
# {21, 34, 78}
