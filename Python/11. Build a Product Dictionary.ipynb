# %%
laptop = {

"brand": "Dell",

"model": "XPS 15",

"price": 120000,

"ram": "16GB",

"storage": "512GB SSD",

"available": True

}

# %%
print(laptop)
# Out:
# {'brand': 'Dell', 'model': 'XPS 15', 'price': 120000, 'ram': '16GB', 'storage': '512GB SSD', 'available': True}

# %%
print(laptop["brand"])
# Out:
# Dell

# %%
print(laptop["model"])
# Out:
# XPS 15

# %%
print(laptop["price"])
# Out:
# 120000

# %%
laptop["price"] = 150000

# %%
print(laptop)
# Out:
# {'brand': 'Dell', 'model': 'XPS 15', 'price': 150000, 'ram': '16GB', 'storage': '512GB SSD', 'available': True}

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 150000,
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True}

# %%
laptop["processor"] = "Intel Core i7"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 150000,
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'Intel Core i7'}

# %%
laptop["GPU"] = "NVidia Gforce RTX 5090"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 150000,
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'Intel Core i7',
#  'GPU': 'NVidia Gforce RTX 5090'}

# %%
laptop["ram"] = "32GB"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 150000,
#  'ram': '32GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'Intel Core i7',
#  'GPU': 'NVidia Gforce RTX 5090'}

# %%
laptop.pop("available")
# Out:
# True

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 150000,
#  'ram': '32GB',
#  'storage': '512GB SSD',
#  'processor': 'Intel Core i7',
#  'GPU': 'NVidia Gforce RTX 5090'}

# %%
print("keys", laptop.keys())
# Out:
# keys dict_keys(['brand', 'model', 'price', 'ram', 'storage', 'processor', 'GPU'])

# %%
print("Values: ", laptop.values())
# Out:
# Values:  dict_values(['Dell', 'XPS 15', 150000, '32GB', '512GB SSD', 'Intel Core i7', 'NVidia Gforce RTX 5090'])

# %%
print("Items: ", laptop.items())
# Out:
# Items:  dict_items([('brand', 'Dell'), ('model', 'XPS 15'), ('price', 150000), ('ram', '32GB'), ('storage', '512GB SSD'), ('processor', 'Intel Core i7'), ('GPU', 'NVidia Gforce RTX 5090')])

# %%
mobile = {
    "brand": "Samasung",
    "model": "Galaxy S26",
    "price": 750000,
    "RAM": "12GB",
    "storage": "512GB",
    "available": True
}

# %%
print(mobile)
# Out:
# {'brand': 'Samasung', 'model': 'Galaxy S26', 'price': 750000, 'RAM': '12GB', 'storage': '512GB', 'available': True}
